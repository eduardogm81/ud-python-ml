# %% [markdown]
# # Carga de datos a través de la función read_csv

# %%
import pandas as pd
import os

# %%
main_path = "../datasets"
file_name = "titanic/titanic3.csv"
# full_path = main_path + "/" + file_name
full_path = os.path.join(main_path, full_path)
# Out:
# '../datasets\\../datasets\\../datasets/titanic/titanic3.csv'

# %%
# data = pd.read_csv("../datasets/titanic/titanic3.csv")
data = pd.read_csv(full_path)

# %%
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# ### Argumentos de read_csv
# - sep: indica el separador, por defecto es la coma.
# - Dtype: indica el tipo de la columna, None es el valor por defecto e indica que es pyhton quien debe de averiguar el tipo. Si queremos cargar columnas es dtype=["a"=np.float64, "b"=np.int32], donde np es NumPy
# - header=none
# - names: [] indicar el nombre de las columnas
# - skiprows: Se salta las lineas
# - skip_blank_lines(True)
#
# data = pd.read_csv("../datasets/titanic/titanic3.csv", sep=",", dtype=None, header=None)

# %%
data2 = pd.read_csv(os.path.join(main_path, "customer-churn-model/Customer Churn Model.txt"))

# %%
data2.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
data2.columns.values
# Out:
# array(['State', 'Account Length', 'Area Code', 'Phone', "Int'l Plan",
#        'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls',
#        'Day Charge', 'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins',
#        'Night Calls', 'Night Charge', 'Intl Mins', 'Intl Calls',
#        'Intl Charge', 'CustServ Calls', 'Churn?'], dtype=object)

# %%
data_cols = pd.read_csv(main_path + "/customer-churn-model/Customer Churn Columns.csv" )
data_cols_list = data_cols["Column_Names"].tolist()
data_cols_list
data2 = pd.read_csv(main_path + "/customer-churn-model/Customer Churn Model.txt", header=None, names=data_cols_list)
data2.head()
# Out:
#        A               B          C         D           E           F  \
# 0  State  Account Length  Area Code     Phone  Int'l Plan  VMail Plan
# 1     KS             128        415  382-4657          no         yes
# 2     OH             107        415  371-7191          no         yes
# 3     NJ             137        415  358-1921          no          no
# 4     OH              84        408  375-9999         yes          no
#
#                G           H          I           J   ...            L  \
# 0  VMail Message    Day Mins  Day Calls  Day Charge   ...    Eve Calls
# 1             25  265.100000        110   45.070000   ...           99
# 2             26  161.600000        123   27.470000   ...          103
# 3              0  243.400000        114   41.380000   ...          110
# 4              0  299.400000         71   50.900000   ...           88
#
#             M           N            O             P          Q           R  \
# ...

# %% [markdown]
# ### Carga de datos a través de la función open
# open -> "r" sólo lectura, "rw" - lectura y escritura

# %%
data3 = open(main_path + "/customer-churn-model/Customer Churn Model.txt", "r")

# %%
data3 = open(main_path + "/customer-churn-model/Customer Churn Model.txt", "r")
cols = data3.readline().strip().split(",")
n_cols = len(cols)

# %%
counter = 0
main_dict = {}
for col in cols:
    main_dict[col] = []

# %%
for line in data3:
    values = line.strip().split(',')
    for i in range(len(cols)):
        main_dict[cols[i]].append(values[i])
    counter += 1

print ("El dataset tiene %d filas y %d columnas" % (counter, n_cols))
# Out:
# El dataset tiene 3334 filas y 21 columnas

# %%
df3 = pd.DataFrame(main_dict)
df3.head
# Out:
# <bound method NDFrame.head of       Account Length  Area Code  Churn?  CustServ Calls  Day Calls  \
# 0     Account Length  Area Code  Churn?  CustServ Calls  Day Calls
# 1                128        415  False.               1        110
# 2                107        415  False.               1        123
# 3                137        415  False.               0        114
# 4                 84        408  False.               2         71
# 5                 75        415  False.               3        113
# 6                118        510  False.               0         98
# 7                121        510  False.               3         88
# 8                147        415  False.               0         79
# 9                117        408  False.               1         97
# 10               141        415  False.               0         84
# 11                65        415   True.               4        137
# 12                74        415  False.               0        127
# ...

# %%
## Lectura y escritura de ficheros

# %%
infile = main_path + "/customer-churn-model/Customer Churn Model.txt"
outfile = main_path + "/customer-churn-model/Tab Customer Churn Model1.txt"

# %%
with open(infile, "r") as infile1:
    with open(outfile, "w") as outfile1:
        for line in infile1:            
            fields = line.strip().split(",")
            outfile1.write("\t".join(fields) + "\n")

# %%
df4 = pd.read_csv(outfile, sep="\t")
df4.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %% [markdown]
# ## Lectura de datos desde una URL externa
#
# Para ello usaremos el enlace http://winterolympicsmedals.com/medals.csv

# %%
medals_url = "http://winterolympicsmedals.com/medals.csv"

# %%
medals_data = pd.read_csv(medals_url)

# %%
medals_data.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
import csv

# %%
import urllib3

http = urllib3.PoolManager()
r = http.request('GET', medals_url)
# r.status, r.data
response = r.data

# %%
import csv

cr = csv.reader(response)

# %%
for row in cr:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-14-3d8bf9431c00> in <module>()
# ----> 1 for row in cr:
#       2     print(row)
#
# Error: iterator should return strings, not int (did you open the file in text mode?)

# %% [markdown]
# ## Ficheros xls y xlsx

# %%
main_path = "../datasets"
file_name = "titanic/titanic3.xls"
file_name2 = "titanic/titanic3.xlsx"

# %%
titanic2 = pd.read_excel(main_path + "/" + file_name, "titanic3")

# %%
titanic3 = pd.read_excel(main_path + "/" + file_name2, "titanic3")

# %%
titanic2.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
titanic3.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# ## Creación de un csv

# %%
titanic3.to_csv(main_path + "/titanic/titanic_custom1.csv")

# %%
titanic3.to_excel(main_path + "/titanic/titanic_custom1.xls")

# %% [markdown]
# ## Tratamiento de datos tras acceder a una URL externa
#
# Vamos a hacer un ejemplo usando la librería urllib3 para leer los datos desde una libreria externa, procesarlos y convertirlos en un dataframe de python antes de guardarlos en un CSV local

# %%
def downloadFromURL(url, filename, sep = ",", delim = "\n", encoding="utf-8" ):
    import pandas as pd
    import os

    # Primero importamos la librería y hacemos la conexión  con la web de los datos
    import urllib3

    medals_url = "http://winterolympicsmedals.com/medals.csv"

    http = urllib3.PoolManager()
    r = http.request('GET', url)
    print ("El estado de la respuesta es %d" % (r.status))
    response = r.data

    # El objeto es un string binario, así que lo convertimos a un string decodificándolo en UTF-8
    str_data = response.decode(encoding)

    # Dividimos el string en un array de filas, separándolo por intros
    lines = str_data.split(delim)

    # La primera linea contiene la cabecera así que la extraemos
    col_names = lines[0].split(sep)
    n_cols = len(col_names)

    # Generamos un diccionario vacío donde irá la información procesada desde la url externa
    counter = 0
    main_dict = {}

    for col in col_names:
        main_dict[col] = []

    # Procesamos fila a fila la información para ir rellenando el diccionario con los datos    
    for line in lines:
        # nos saltamos la primera linea que es la que contiene la cabecera
        if (counter > 0):
            # Dividimos cada string por las comas como elemento separador
            values = line.strip().split(sep)
            # Añadimos cada valor a su respectiva columna del diccionario
            for i in range(len(col_names)):
                main_dict[col_names[i]].append(values[i])
        counter += 1

    print("El dataset tiene %d filas y %d columnas" % (counter, n_cols))


    # Convertimos el diccionario procesado a Data frame y comprobamos que los datos
    # son correctos
    df = pd.DataFrame(main_dict)
    # print(df.head())


    # Elegimos donde guardarlo (en la carpeta athletes es donde tiene más sentido 
    # por el contenido del análisis)
    cwd = os.getcwd()
    # print('cwd: ' + cwd)
    mainpath = os.path.join(cwd, "../datasets")
    # filename = "athletes/downloaded_medals1."
    fullpath = os.path.join(mainpath, filename)

    # Lo guardamos en CSV, JSON o excel
    df.to_csv(fullpath + ".csv")
    df.to_json(fullpath + ".json")
    df.to_excel(fullpath + ".xls")
    
    return df

# %%
medals_df = downloadFromURL("http://winterolympicsmedals.com/medals.csv", "athletes/downloaded_medals1")
medals_df.head()
# Out:
# El estado de la respuesta es 200
# El dataset tiene 2312 filas y 8 columnas
# Head
#        City      Discipline       Event Event gender   Medal  NOC       Sport  \
# 0  Chamonix  Figure skating  individual            M  Silver  AUT     Skating
# 1  Chamonix  Figure skating  individual            W    Gold  AUT     Skating
# 2  Chamonix  Figure skating       pairs            X    Gold  AUT     Skating
# 3  Chamonix       Bobsleigh    four-man            M  Bronze  BEL   Bobsleigh
# 4  Chamonix      Ice Hockey  ice hockey            M    Gold  CAN  Ice Hockey
#
#    Year
# 0  1924
# 1  1924
# 2  1924
# 3  1924
# 4  1924
